# %% [markdown]
# ### Type Hints
# For example, Python will let us call ```dollar_to_euro_with_defaults(True, "abc")```, but it will then fail because multiplication isn't defined between bools and string.

# %%
def dollar_to_euro_with_defaults(dollar_amout: float, convertion_rate: float = 0.93) -> float:
  return dollar_amout * convertion_rate
