# %% [markdown]
# ###  **1.5. DataFrame Relational Operations in Spark**
#
# This demonstration will show how to effectively use joins and set operations with DataFrames, focusing on performance optimization and best practices
#
# ####  **Objectives**
# * Understand differnt types of DataFrame joins
# * Implement performance optimization for joins
# * Handle complex join scenarios
# * Use set operations effectively
# * Apply best practices for data skew

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# Create a the first SparkSession
spark = SparkSession.builder.appName("Relational Operations").getOrCreate()
